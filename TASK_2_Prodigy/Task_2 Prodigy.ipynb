# %%
#Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the csv file from location
file_path = "E:\COMPUTER SCIENCE\PRODIGY_INTERNSHIP\TASK_2_Prodigy\Titanic.csv"
data = pd.read_csv(file_path)
#printing the first three(0,1) rows with columns.
data.head(2)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3313414348.py:2: SyntaxWarning: invalid escape sequence '\C'
#   file_path = "E:\COMPUTER SCIENCE\PRODIGY_INTERNSHIP\TASK_2_Prodigy\Titanic.csv"
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
print(data.shape)
print("           ")
print("           ")
print(data.info())
# Out:
# (891, 12)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(data.isnull().sum())
"""Shows there are about 177 null/empty values in Age & Cabin has about
687 empty ones. While Embarked has 2 mmissing values."""
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 'Shows there are about 177 null/empty values in Age & Cabin has about\n687 empty ones. While Embarked has 2 mmissing values.'

# %%
"""We are dropping the "Cabin" section as it is overflowing 
with null values & it is not very important for our future analysis."""
data.drop(columns="Cabin",axis=1,inplace=True)

# %%
"""Performing EDA on 'Age' as it has about 177 null values, we are
using the mean() function to fill."""
data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3555961870.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\1523684883.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data['Survived'].value_counts()
#i.e., Survived and Not-Survived into 0 & 1.
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived',data=data,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not_Survived','Survived'])
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\1604309981.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data=data,palette='viridis',)

# %%
plt.pie(data['Survived'].value_counts(),explode=[0,0.04],
        autopct="%1.2f%%",
        labels=['Not survived','Survived'])
plt.title("Survival of people")
plt.show()

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.countplot(x='Sex',data=data,palette='viridis',)
plt.xlabel("Gender")
plt.ylabel("Number of people")
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\2943646363.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex',data=data,palette='viridis',)

# %%
sns.countplot(x='Survived',hue='Sex',data=data,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
data[data['Sex'] == 'male'].Survived.groupby(data.Survived).count().plot(kind='pie',
figsize=(3, 6),explode=[0,0.05],autopct='%1.1f%%',labels=["Not survived","Survived"])
plt.ylabel("")
plt.title("Male survival rate")
plt.show()

# %%
data[data['Sex'] == 'female'].Survived.groupby(data.Survived).count().plot(kind='pie',
figsize=(3, 6),explode=[0,0.05],autopct='%1.1f%%',labels=["Not survived","Survived"])
plt.ylabel("")
plt.title("Female survival rate")
plt.show()

# %%
sns.countplot(x='Pclass',data=data,palette='viridis',)
plt.xlabel("Pclass")
plt.ylabel("Number of people")
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3660176574.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass',data=data,palette='viridis',)

# %%
sns.countplot(x='Embarked',data=data,palette='coolwarm',)
plt.xlabel("Embarked")
plt.ylabel("Number of people")
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\1690484920.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Embarked',data=data,palette='coolwarm',)

# %%
sns.countplot(x='Survived',hue='Embarked',data=data,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
fig,axes = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(x='SibSp',data=data,ax=axes[0],palette='husl')
sns.countplot(x='Parch',data=data,ax=axes[1],palette='husl')
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3662100299.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SibSp',data=data,ax=axes[0],palette='husl')
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3662100299.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Parch',data=data,ax=axes[1],palette='husl')

# %%
print("Unique values in 'Survived'" , data['Survived'].unique())
print("Unique values in 'SibSp':" ,data['SibSp'].unique())

print("Seaborn Version:", sns.__version__)

print("Plotting with 'deep' palette")
try:
    sns.countplot(x ='Survived', hue='Parch',data=data,
                  palette = 'deep')
    plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
    plt.xlabel("Survival status")
    plt.ylabel("Number of people")
    plt.title("Survival population of Parch")
    plt.show()
    
except Exception as e:
    print("Ignore:",e)
print("                                   ")
print("                                   ")
print("                                   ")
# Out:
# Unique values in 'Survived' [0 1]
# Unique values in 'SibSp': [1 0 3 4 2 5 8]
# Seaborn Version: 0.13.2
# Plotting with 'deep' palette

# %%
fig,axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(data['Fare'], kde=True,ax=axes[0])
sns.histplot(data['Age'].dropna(),kde=True,ax=axes[1])
plt.show()

# %%
# Define cut points and label names
cut_points = [ 0, 5, 12, 18, 35, 60, 100]
label_names = [ 'Infant', "Child", 'Teenager', "Young Adult", 'Adult', 'Senior']

# Create the "Age_categories" column
data['Age_categories'] = pd.cut(data['Age'], bins=cut_points, labels=label_names,
                                right=False)

# Creating a pivot table for survival rates based on age categories
age_cat_pivot = data.pivot_table(index="Age_categories", 
                                 values="Survived")

# Define colors for each bar
colors = ['blue', 'green', 'orange', 'purple', 'pink', 'brown']

# Plotting the bar chart with different colors for each bar
fig, ax = plt.subplots()
bars = ax.bar(age_cat_pivot.index, age_cat_pivot['Survived'], 
              color=colors)

# Adding a legend with the specified colors
handles = [plt.Rectangle((0, 0), 1, 1, color=colors[i]) for i in
range(len(colors))]
ax.legend(handles, label_names)
ax.set_title('Survival Rates by Age Category')
ax.set_xlabel('Age Category')
ax.set_ylabel('Survival Rate')
plt.xticks(rotation=40)
plt.show()
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\2553234979.py:10: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   age_cat_pivot = data.pivot_table(index="Age_categories",

# %%
sns.histplot(x='Fare',hue='Survived',data=data,kde=True)
plt.legend(labels=['survived','not survived'])
plt.show()

# %%
sns.histplot(x='Age',hue='Survived',data=data,kde=True)
plt.legend(labels=['survived','not survived'])
plt.show()

# %%
data.replace({'Sex':{'male':1,'female':0},
            'Embarked':{'S':0,'C':1,'Q':2}},
           inplace=True)
# Out:
# C:\Users\Sathiadev.T.M\AppData\Local\Temp\ipykernel_8648\3130630068.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Sex':{'male':1,'female':0},

# %%
df_num = data[['Fare','Parch','SibSp','Age','Sex','Pclass','Embarked','Survived']]
